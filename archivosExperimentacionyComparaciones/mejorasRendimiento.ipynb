# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

BladeRunner_480_2049 = 2511182.880000

Deadpool_480 = 2513042.640000

It_480 = 2470164.480000

JusticeLeague_480 = 2518416.720000

TheMandalorian_480 = 2540713.680000


BladeRunner_720_2049 = 6600252.960000

Deadpool_720 = 6432651.360000

It_720 = 6446297.520000

JusticeLeague_720 = 6550801.200000

TheMandalorian_720 = 6544332.720000




BladeRunner_1080_2049 = 16683511.680000

Deadpool_1080 = 16734023.280000

It_1080 = 16323879.600000

JusticeLeague_1080 = 16767185.040000

TheMandalorian_1080 = 16780484.880000




BladeRunner_4k_2049 = 95538715.200000

Deadpool_4k = 95458779.360000

It_4k = 94874941.440000

JusticeLeague_4k = 95363869.680000

TheMandalorian_4k = 96213191.040000


p480_NOOP = pd.Series([BladeRunner_480_2049, Deadpool_480, It_480, JusticeLeague_480, TheMandalorian_480])

p720_NOOP = pd.Series([BladeRunner_720_2049, Deadpool_720, It_720, JusticeLeague_720, TheMandalorian_720])

p1080_NOOP = pd.Series([BladeRunner_1080_2049, Deadpool_1080, It_1080, JusticeLeague_1080, TheMandalorian_1080])

p4k_NOOP = pd.Series([BladeRunner_4k_2049, Deadpool_4k, It_4k, JusticeLeague_4k, TheMandalorian_4k])

# %%
BladeRunner_480_2049 = 2449348.56

Deadpool_480 = 2399014.800000

It_480 = 2303616.960000

JusticeLeague_480 = 2441611.440000

TheMandalorian_480 = 2408186.880000


BladeRunner_720_2049 = 6193829.520000

Deadpool_720 = 6338588.400000

It_720 = 6062659.920000

JusticeLeague_720 = 6237033.840000

TheMandalorian_720 = 6241702.320000




BladeRunner_1080_2049 = 14388911.280000

Deadpool_1080 = 14356015.920000

It_1080 = 14497427.520000

JusticeLeague_1080 = 14496924.960000

TheMandalorian_1080 = 14278234.320000




BladeRunner_4k_2049 = 86824092.240000

Deadpool_4k = 87380110.800000

It_4k = 86591793.600000

JusticeLeague_4k = 87137264.880000

TheMandalorian_4k = 87043600.080000


p480_EXP1 = pd.Series([BladeRunner_480_2049, Deadpool_480, It_480, JusticeLeague_480, TheMandalorian_480])

p720_EXP1 = pd.Series([BladeRunner_720_2049, Deadpool_720, It_720, JusticeLeague_720, TheMandalorian_720])

p1080_EXP1 = pd.Series([BladeRunner_1080_2049, Deadpool_1080, It_1080, JusticeLeague_1080, TheMandalorian_1080])

p4k_EXP1 = pd.Series([BladeRunner_4k_2049, Deadpool_4k, It_4k, JusticeLeague_4k, TheMandalorian_4k])

# %%
BladeRunner_480_2049 = 2492616.960000

Deadpool_480 = 2458543.680000

It_480 = 2363763.600000

JusticeLeague_480 = 2496543.840000

TheMandalorian_480 = 2471567.040000


BladeRunner_720_2049 = 6311152.080000

Deadpool_720 = 6279733.440000

It_720 = 6087798.000000

JusticeLeague_720 = 6299963.280000

TheMandalorian_720 = 6462017.280000




BladeRunner_1080_2049 = 14761139.760000

Deadpool_1080 = 15034584.960000

It_1080 = 14838512.400000

JusticeLeague_1080 = 14811045.120000

TheMandalorian_1080 = 14899647.600000




BladeRunner_4k_2049 = 87062877.360000

Deadpool_4k = 87858596.160000

It_4k = 87602086.800000

JusticeLeague_4k = 87251945.040000

TheMandalorian_4k = 87866260.560000


p480_EXP2 = pd.Series([BladeRunner_480_2049, Deadpool_480, It_480, JusticeLeague_480, TheMandalorian_480])

p720_EXP2 = pd.Series([BladeRunner_720_2049, Deadpool_720, It_720, JusticeLeague_720, TheMandalorian_720])

p1080_EXP2 = pd.Series([BladeRunner_1080_2049, Deadpool_1080, It_1080, JusticeLeague_1080, TheMandalorian_1080])

p4k_EXP2 = pd.Series([BladeRunner_4k_2049, Deadpool_4k, It_4k, JusticeLeague_4k, TheMandalorian_4k])

# %%
p480_EXP1_mejora = p480_NOOP-p480_EXP1
p720_EXP1_mejora = p720_NOOP-p720_EXP1
p1080_EXP1_mejora = p1080_NOOP-p1080_EXP1
p4k_EXP1_mejora = p4k_NOOP-p4k_EXP1


p480_EXP1_mejora_porcentual = (p480_EXP1_mejora/p480_NOOP)*100
p720_EXP1_mejora_porcentual = (p720_EXP1_mejora/p720_NOOP)*100
p1080_EXP1_mejora_porcentual = (p1080_EXP1_mejora/p1080_NOOP)*100
p4k_EXP1_mejora_porcentual = (p4k_EXP1_mejora/p4k_NOOP)*100

# %%
labels = ['BladeRunner', 'Deadpool', 'IT', 'Justice League', 'The Mandalorian']

x = np.arange(5)
width = 0.8
fig, ((ax,ax2),(ax3,ax4)) = plt.subplots(2,2)

rects480 = ax.bar(x,p480_EXP1_mejora, width,label='480p')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mejora en la cantidad de ciclos')
ax.set_xlabel('Foto')
ax.set_title('480p, filtro Gamma')
ax.set_xticks(x)
ax.set_xticklabels(labels)
#ax.legend()

rects1 = ax2.bar(x  ,p720_EXP1_mejora,width, label='Corrida 1')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Mejora en la cantidad de ciclos')
ax2.set_xlabel('Foto')
ax2.set_title('720p, filtro Gamma')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
#ax2.legend()

rects1 = ax3.bar(x  ,p1080_EXP1_mejora,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Mejora en la cantidad de ciclos')
ax3.set_xlabel('Foto')
ax3.set_title('1080p, filtro Gamma')
ax3.set_xticks(x)
ax3.set_xticklabels(labels)
#ax3.legend()

rects1 = ax4.bar(x  ,p4k_EXP1_mejora,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax4.set_ylabel('Mejora en la cantidad de ciclos')
ax4.set_xlabel('Foto')
ax4.set_title('4k, filtro Gamma')
ax4.set_xticks(x)
ax4.set_xticklabels(labels)
#ax3.legend()


#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects1b, padding=3)
#fig.tight_layout()
#ax.set_ylim(0,4*(10**6))
#ax2.set_ylim(0,9*(10**6))
#ax3.set_ylim(0,3*(10**7))
#ax4.set_ylim(0,1.5*(10**8))



fig.tight_layout()
fig.set_figheight(10)
fig.set_figwidth(17)
plt.savefig('MEJORAS EXP1.jpg')

plt.show()

# %%
labels = ['BladeRunner', 'Deadpool', 'IT', 'Justice League', 'The Mandalorian']

x = np.arange(5)
width = 0.8
fig, ((ax,ax2),(ax3,ax4)) = plt.subplots(2,2)

rects480 = ax.bar(x,p480_EXP1_mejora_porcentual, width,label='480p')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Porcentaje de mejora en la cantidad de ciclos')
ax.set_xlabel('Foto')
ax.set_title('480p, filtro Gamma')
ax.set_xticks(x)
ax.set_xticklabels(labels)
#ax.legend()

rects1 = ax2.bar(x  ,p720_EXP1_mejora_porcentual,width, label='Corrida 1')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Porcentaje de mejora en la cantidad de ciclos')
ax2.set_xlabel('Foto')
ax2.set_title('720p, filtro Gamma')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
#ax2.legend()

rects1 = ax3.bar(x  ,p1080_EXP1_mejora_porcentual,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Porcentaje de mejora en la cantidad de ciclos')
ax3.set_xlabel('Foto')
ax3.set_title('1080p, filtro Gamma')
ax3.set_xticks(x)
ax3.set_xticklabels(labels)
#ax3.legend()

rects1 = ax4.bar(x  ,p4k_EXP1_mejora_porcentual,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax4.set_ylabel('Porcentaje de mejora en la cantidad de ciclos')
ax4.set_xlabel('Foto')
ax4.set_title('4k, filtro Gamma')
ax4.set_xticks(x)
ax4.set_xticklabels(labels)
#ax3.legend()


#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects1b, padding=3)
#fig.tight_layout()
#ax.set_ylim(0,4*(10**6))
#ax2.set_ylim(0,9*(10**6))
#ax3.set_ylim(0,3*(10**7))
#ax4.set_ylim(0,1.5*(10**8))



fig.tight_layout()
fig.set_figheight(10)
fig.set_figwidth(17)
plt.savefig('MEJORASporcentuales EXP1.jpg')

plt.show()

# %%
p480_EXP2_mejora = p480_NOOP-p480_EXP2
p720_EXP2_mejora = p720_NOOP-p720_EXP2
p1080_EXP2_mejora = p1080_NOOP-p1080_EXP2
p4k_EXP2_mejora = p4k_NOOP-p4k_EXP2


p480_EXP2_mejora_porcentual = (p480_EXP2_mejora/p480_NOOP)*100
p720_EXP2_mejora_porcentual = (p720_EXP2_mejora/p720_NOOP)*100
p1080_EXP2_mejora_porcentual = (p1080_EXP2_mejora/p1080_NOOP)*100
p4k_EXP2_mejora_porcentual = (p4k_EXP2_mejora/p4k_NOOP)*100

# %%
labels = ['BladeRunner', 'Deadpool', 'IT', 'Justice League', 'The Mandalorian']

x = np.arange(5)
width = 0.8
fig, ((ax,ax2),(ax3,ax4)) = plt.subplots(2,2)

rects480 = ax.bar(x  ,p480_EXP2_mejora, width,label='480p')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mejora en la cantidad de ciclos')
ax.set_xlabel('Foto')
ax.set_title('480p, filtro Gamma')
ax.set_xticks(x)
ax.set_xticklabels(labels)
#ax.legend()

rects1 = ax2.bar(x ,p720_EXP2_mejora,width, label='Corrida 1')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Mejora en la cantidad de ciclos')
ax2.set_xlabel('Foto')
ax2.set_title('720p, filtro Gamma')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
#ax2.legend()

rects1 = ax3.bar(x  ,p1080_EXP2_mejora,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Mejora en la cantidad de ciclos')
ax3.set_xlabel('Foto')
ax3.set_title('1080p, filtro Gamma')
ax3.set_xticks(x)
ax3.set_xticklabels(labels)
#ax3.legend()

rects1 = ax4.bar(x ,p4k_EXP2_mejora,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax4.set_ylabel('Mejora en la cantidad de ciclos')
ax4.set_xlabel('Foto')
ax4.set_title('4k, filtro Gamma')
ax4.set_xticks(x)
ax4.set_xticklabels(labels)
#ax3.legend()


#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects1b, padding=3)
#fig.tight_layout()
#ax.set_ylim(0,4*(10**6))
#ax2.set_ylim(0,9*(10**6))
#ax3.set_ylim(0,3*(10**7))
#ax4.set_ylim(0,1.5*(10**8))



fig.tight_layout()
fig.set_figheight(10)
fig.set_figwidth(17)
plt.savefig('MEJORAS EXP2.jpg')

plt.show()

# %%
labels = ['BladeRunner', 'Deadpool', 'IT', 'Justice League', 'The Mandalorian']

x = np.arange(5)
width = 0.8
fig, ((ax,ax2),(ax3,ax4)) = plt.subplots(2,2)

rects480 = ax.bar(x  ,p480_EXP2_mejora_porcentual, width,label='480p')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mejora en la cantidad de ciclos')
ax.set_xlabel('Foto')
ax.set_title('480p, filtro Gamma')
ax.set_xticks(x)
ax.set_xticklabels(labels)
#ax.legend()

rects1 = ax2.bar(x ,p720_EXP2_mejora_porcentual,width, label='Corrida 1')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Mejora en la cantidad de ciclos')
ax2.set_xlabel('Foto')
ax2.set_title('720p, filtro Gamma')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
#ax2.legend()

rects1 = ax3.bar(x  ,p1080_EXP2_mejora_porcentual,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Mejora en la cantidad de ciclos')
ax3.set_xlabel('Foto')
ax3.set_title('1080p, filtro Gamma')
ax3.set_xticks(x)
ax3.set_xticklabels(labels)
#ax3.legend()

rects1 = ax4.bar(x ,p4k_EXP2_mejora_porcentual,width, label='Corrida 1')
#rects1b = ax3.bar(x + width/2 ,gamma_means[5:], width,label='Corrida 2')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax4.set_ylabel('Mejora en la cantidad de ciclos')
ax4.set_xlabel('Foto')
ax4.set_title('4k, filtro Gamma')
ax4.set_xticks(x)
ax4.set_xticklabels(labels)
#ax3.legend()


#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects1b, padding=3)
#fig.tight_layout()
#ax.set_ylim(0,4*(10**6))
#ax2.set_ylim(0,9*(10**6))
#ax3.set_ylim(0,3*(10**7))
#ax4.set_ylim(0,1.5*(10**8))



fig.tight_layout()
fig.set_figheight(10)
fig.set_figwidth(17)
plt.savefig('MEJORAS_porcentuales EXP2.jpg')

plt.show()
